# %%
import pandas as pd 
import numpy as np


df = pd.read_csv('https://raw.githubusercontent.com/haiyen040602/KPDLHLV/master/merged_data_ver5.csv', index_col=0)
# df2 = pd.read_csv('https://raw.githubusercontent.com/haiyen040602/KPDLHLV/master/merged_ver2.csv', index_col=0)

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.tree import DecisionTreeRegressor

# %%
X = df.drop(['sim_number', 'price_vnd'], 1)
y = df['price_vnd']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.

# %%
X_train, X_test, y_train, y_test = train_test_split(X.values, y.values, random_state= 42, test_size=0.1, shuffle=True)
X_train = X.values
y_train = y.values

# %%
from sklearn.metrics import mean_squared_error as MSE

# %%
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# #Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

import sklearn.metrics as sm

regr = RandomForestRegressor()
regr.fit(X_train, y_train)

pred = regr.predict(X_test)

# RMSE Computation
rmse = np.sqrt(MSE(y_test, pred))
print("RMSE : % f" %(rmse))

print("Predicted values are: ", pred[:15])
print("Real values are: ", y_test[:15])

print("Root mean squared error = %f" %rmse) 
print("Mean absolute error =", round(sm.mean_absolute_error(y_test, pred), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, pred), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, pred), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test,pred), 2)) 
print("R2 score =", round(sm.r2_score(y_test, pred), 2))
# Out:
# RMSE :  51905513.895750
# Predicted values are:  [ 3791250.97304797  1310604.78413752  9678888.88888889  3555928.78354568
#   3791250.97304797  3791250.97304797  3555928.78354568   986320.04735744
#  32580216.74322409   674842.81124527  5292440.47619048  2298218.64379283
#   1343265.46241008  2175402.78791334 16633549.70447271]
# Real values are:  [  450000   450000 10000000   450000   500000   500000   450000  1000000
#  70000000   450000  3000000   500000   450000   450000 69000000]
# Root mean squared error = 51905513.895750
# Mean absolute error = 7535953.49
# Mean squared error = 2694182372781881.0
# Median absolute error = 1798218.64
# Explain variance score = 0.68
# R2 score = 0.68

# %%
import pickle
# save the model to disk
filename = '/content/drive/MyDrive/Colab Notebooks/KHAI PHÁ DỮ LIỆU HƯỚNG LĨNH VỰC/Final/Randumforest_model.sav'
pickle.dump(regr, open(filename, 'wb'))
# some time later...

# %% [markdown]
# #Các mô hình khác

# %%
model = DecisionTreeRegressor()
model.fit(X_train, y_train)
# evaluate the model
yhat1 = model.predict(X_test)
# evaluate predictions
mae1 = mean_absolute_error(y_test, yhat1)
rmse1 = np.sqrt(mean_squared_error(y_test, yhat1))

print("Predicted values are: ", yhat1[:15])
print("Real values are: ", y_test[:15])

import sklearn.metrics as sm
print("Root mean squared error = %f" %rmse1 ) 
print("Mean absolute error =", round(sm.mean_absolute_error(y_test, yhat1), 2)) 
print("Mean squared error =", round(sm.mean_squared_error(y_test, yhat1), 2)) 
print("Median absolute error =", round(sm.median_absolute_error(y_test, yhat1), 2)) 
print("Explain variance score =", round(sm.explained_variance_score(y_test,yhat1), 2)) 
print("R2 score =", round(sm.r2_score(y_test, yhat1), 2))
# Out:
# Predicted values are:  [ 3757581.2543554   1277046.2633452  10000000.          3441057.99151344
#   3757581.2543554   3757581.2543554   3441057.99151344  1000000.
#  33900000.           675467.09991877  5500000.          2396635.25963149
#   1330799.2202729   2174993.83078731 16250781.25      ]
# Real values are:  [  450000   450000 10000000   450000   500000   500000   450000  1000000
#  70000000   450000  3000000   500000   450000   450000 69000000]
# Root mean squared error = 38975990.440377
# Mean absolute error = 6586858.03
# Mean squared error = 1519127830808366.8
# Median absolute error = 1733684.45
# Explain variance score = 0.82
# R2 score = 0.82

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
pred = model.predict(X_test)
 
# RMSE Computation
rmse = np.sqrt(MSE(y_test, pred))
print("RMSE : % f" %(rmse))
# Out:
# RMSE :  84242113.440757

# %%
from sklearn.linear_model import Lasso

reg = Lasso(alpha=1)
reg.fit(X_train, y_train)
pred = reg.predict(X_test)

# RMSE Computation
rmse = np.sqrt(MSE(y_test, pred))
print("RMSE : % f" %(rmse))
print("MSE : % f" %(MSE(y_test, pred)))
# Out:
# RMSE :  84242124.152150
# MSE :  7096735481666272.000000

# %%
from sklearn.svm import SVR
from sklearn.svm import LinearSVR
svr = LinearSVR()
svr.fit(X_train, y_train)
pred = svr.predict(X_test)

# RMSE Computation
rmse = np.sqrt(MSE(y_test, pred))
print("RMSE : % f" %(rmse))
# Out:
# RMSE :  92095423.690392

# %%
from xgboost import XGBRegressor
XGB_m = XGBRegressor()
XGB_m.fit(X_train, y_train)
pred = XGB_m.predict(X_test)
 
# RMSE Computation
rmse = np.sqrt(MSE(y_test, pred))
print("RMSE : % f" %(rmse))
# Out:
# [17:28:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RMSE :  75762887.818894

# %%
from lightgbm import LGBMRegressor
model_lgbm = LGBMRegressor()
model_lgbm.fit(X_train, y_train)
pred = model_lgbm.predict(X_test)
 
# RMSE Computation
rmse = np.sqrt(MSE(y_test, pred))
print("RMSE : % f" %(rmse))
# Out:
# RMSE :  103019537.217182
